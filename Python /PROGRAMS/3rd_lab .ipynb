# %% [markdown]
# <h1>  LAB 3 </h1>

# %% [markdown]
# ## Experiment NO: 5a

# %% [markdown]
# ### Write a program to plot a graph  y= x^4 +5

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define x and y
x = np.linspace(-10, 10, 500)
y = x**4 + 5

# Plot the graph
plt.plot(x, y, label='y = x^4 + 5', color='blue')
plt.title('Graph of y = x^4 + 5')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Exp No 5b

# %% [markdown]
# ###  Write a program to plot normal and stem graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define data
x = np.linspace(0, 10, 50)
y = np.sin(x)

# Plot normal graph
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.plot(x, y, label='Normal Graph', color='blue')
plt.title('Normal Graph')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid()

## plt.show()

# Plot stem graph
plt.subplot(1, 2, 2)
plt.stem(x, y, linefmt='red', markerfmt='ro', basefmt='black', use_line_collection=True)
plt.title('Stem Graph')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_13368\1315268037.py:22: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x, y, linefmt='red', markerfmt='ro', basefmt='black', use_line_collection=True)

# %% [markdown]
# ###  ExpNO: 5c

# %% [markdown]
# <h3> The area of the various continent of the world are  as follows  </h3>
#
#  <br>
#
#         continents = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America', 'Soviet Union']
#         areas = [11.7, 10.4, 1.9, 9.4, 3.3, 6.9, 7.9]
#
#
# <h3> Drow a bar chart reprsenting the given data  </h3>

# %%
import matplotlib.pyplot as plt

# Data
continents = ['Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America', 'Soviet Union']
areas = [11.7, 10.4, 1.9, 9.4, 3.3, 6.9, 7.9]

# Plot bar chart
plt.bar(continents, areas, color='skyblue')
plt.title('Areas of Continents (in million square miles)')
plt.xlabel('Continents')
plt.ylabel('Area (million square miles)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## ExpNO 5d

# %% [markdown]
# ###  write a program to drow the input and output graph of full wave rectifer in single graph

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define time and input signal
t = np.linspace(0, 2 * np.pi, 500)

input_signal = np.sin(t)

output_signal = np.abs(np.sin(t))

# Plot input and output signals
plt.plot(t, input_signal, label='Input Signal (sin(t))', color='blue')
plt.plot(t, output_signal, label='Output Signal (Full-Wave Rectified)', color='red', linestyle='--')
plt.title('Full-Wave Rectifier Input and Output')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## ExpNo: 5e

# %% [markdown]
# ### Draw the histogram of the following
#
#         heights = ['135-140', '140-145', '145-150', '150-155']
#         students = [4, 12, 16, 8]

# %%
import matplotlib.pyplot as plt

# Data
heights = ['135-140', '140-145', '145-150', '150-155']
students = [4, 12, 16, 8]

# Plot histogram
plt.bar(heights, students, color='purple', width=0.4)
plt.title('Histogram of Student Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Number of Students')
plt.grid(axis='y', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Exp_No: 6

# %% [markdown]
# <h1> if x is binomially distubuted with 6 trials and a porbabil

# %%
from math import comb

n = 6
p = 0.25
k = 4

# Calculate P(X = 4)
P_X_4 = comb(n, k) * (p**k) * ((1-p)**(n-k))
print(f"Probability of exactly 4 successes: {P_X_4}")
## 2

# Calculate P(X >= 1)
P_X_0 = comb(n, 0) * (p**0) * ((1-p)**n)
P_X_ge_1 = 1 - P_X_0
print(f"Probability of at least one success: {P_X_ge_1}")
# Out:
# Probability of exactly 4 successes: 0.032958984375
# Probability of at least one success: 0.822021484375

# %% [markdown]
# ## Exp No: 6 b

# %%
from math import exp, factorial

lam = 3.4
k = 6

# Calculate P(X = 6)
P_X_6 = (lam**k * exp(-lam)) / factorial(k)
print(f"P(X = 6) for Poisson distribution: {P_X_6}")
# Out:
# P(X = 6) for Poisson distribution: 0.07160440945982204
